# %% [markdown]
# # Clean Median Income Data
#
# ### 1. Import Libraries and Dataset
# ### 2. Clean and Prepare Data
# ### 3. Transpose Data
# ### 4. Export Datasets

# %% [markdown]
# ## Import Libraries and Dataset

# %% [markdown]
# Import Libraries

# %%
# Import libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Import Data

# %%
# path shortcut
path = r'C:\Users\kacee\OneDrive\Desktop\Project6'

# %%
# Importing Income data
df_inc = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Median_Income_By_State.csv'), index_col = False)

# %% [markdown]
# Inspect Data Shape

# %%
df_inc.head()
# Out:
#       State           2022          2022.1           2021          2021.1  \
# 0       NaN  Median income  Standard error  Median income  Standard error
# 1   Alabama          59910            1934          56930            2294
# 2    Alaska          89740            4842          81130            3967
# 3   Arizona          73450            4123          70820            3394
# 4  Arkansas          53980            2376          50780            1440
#
#             2020          2020.1           2019          2019.1  \
# 0  Median income  Standard error  Median income  Standard error
# 1          54690            2563          56200            2512
# 2          74750            3557          78390            6685
# 3          67090            3409          70670            3391
# 4          50780            1837          54540            2384
#
#             2018  ...           1988          1988.1           1987  \
# ...

# %%
df_inc.shape
# Out:
# (52, 83)

# %%
df_inc.columns
# Out:
# Index(['State', '2022', '2022.1', '2021', '2021.1', '2020', '2020.1', '2019',
#        '2019.1', '2018', '2018.1', '2017', '2017.1', '2017.2', '2017.3',
#        '2016', '2016.1', '2015', '2015.1', '2014', '2014.1', '2013', '2013.1',
#        '2013.2', '2013.3', '2012', '2012.1', '2011', '2011.1', '2010',
#        '2010.1', '2009', '2009.1', '2008', '2008.1', '2007', '2007.1', '2006',
#        '2006.1', '2005', '2005.1', '2004', '2004.1', '2003', '2003.1', '2002',
#        '2002.1', '2001', '2001.1', '2000', '2000.1', '1999', '1999.1', '1998',
#        '1998.1', '1997', '1997.1', '1996', '1996.1', '1995', '1995.1', '1994',
#        '1994.1', '1993', '1993.1', '1992', '1992.1', '1991', '1991.1', '1990',
#        '1990.1', '1989', '1989.1', '1988', '1988.1', '1987', '1987.1', '1986',
#        '1986.1', '1985', '1985.1', '1984', '1984.1'],
#       dtype='object')

# %% [markdown]
# ## Clean and Prepare Data

# %% [markdown]
# Drop Unnecessary Columns

# %%
# Drop unnecessary columns (All year columns ending in .1, They are adjustments that are not necessary to keep)(Also all years before 2008)
df_inco = df_inc.drop(columns =['2022.1', '2021.1', '2020.1', '2019.1', '2018.1', '2017.1', '2017.2', '2017.3', '2016.1', '2015.1', '2014.1', '2013.1', '2013.2', '2013.3', '2012.1', '2011.1', '2010.1', '2009.1', '2008.1', '2007', '2007.1', '2006', '2006.1', '2005', '2005.1', '2004', '2004.1', '2003', '2003.1', '2002', '2002.1', '2001', '2001.1', '2000', '2000.1', '1999', '1999.1', '1998', '1998.1', '1997', '1997.1', '1996', '1996.1', '1995', '1995.1', '1994', '1994.1', '1993', '1993.1', '1992', '1992.1', '1991', '1991.1', '1990', '1990.1', '1989', '1989.1', '1988', '1988.1', '1987', '1987.1', '1986', '1986.1', '1985', '1985.1', '1984', '1984.1'])

# %%
df_inco.columns
# Out:
# Index(['State', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2010', '2009', '2008'],
#       dtype='object')

# %%
df_inco.shape
# Out:
# (52, 16)

# %%
df_inco.head(20)
# Out:
#                    State           2022           2021           2020  \
# 0                    NaN  Median income  Median income  Median income
# 1                Alabama          59910          56930          54690
# 2                 Alaska          89740          81130          74750
# 3                Arizona          73450          70820          67090
# 4               Arkansas          53980          50780          50780
# 5             California          85300          81580          77650
# 6               Colorado          89930          84950          83780
# 7            Connecticut          90730          80960          79430
# 8               Delaware          80750          68690          70020
# 9   District of Columbia         101700          90640          88220
# 10               Florida          65370          59730          57760
# 11               Georgia          67730          61500          59270
# ...

# %%
# Drop Median Income Row
df_incom = df_inco.drop([0])

# %%
df_incom.head()
# Out:
#         State   2022   2021   2020   2019   2018   2017   2016   2015   2014  \
# 1     Alabama  59910  56930  54690  56200  49940  50870  47220  44510  42280
# 2      Alaska  89740  81130  74750  78390  68730  77990  75720  75110  67630
# 3     Arizona  73450  70820  67090  70670  62280  59700  57100  52250  49250
# 4    Arkansas  53980  50780  50780  54540  49780  49750  45910  42800  44920
# 5  California  85300  81580  77650  78110  70490  70040  66640  63640  60490
#
#     2013   2012   2011   2010   2009   2008
# 1  47320  43460  42590  40930  39980  44480
# 2  72470  63650  57430  57850  61600  63990
# 3  52610  47040  48620  46900  45740  46910
# 4  39380  39020  41300  38590  36540  39590
# 5  60790  57020  53370  54280  56130  57010

# %%
df_incom.shape
# Out:
# (51, 16)

# %% [markdown]
# Look for Mixed Data Types

# %%
# Mixed data in df_incom
for col in df_incom.columns.tolist():
  weird = (df_incom[[col]].applymap(type) != df_incom[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_incom[weird]) > 0:
    print (col)

# %%
# Check data types of df_incom
df_incom.dtypes
# Out:
# State    object
# 2022     object
# 2021     object
# 2020     object
# 2019     object
# 2018     object
# 2017     object
# 2016     object
# 2015     object
# 2014     object
# 2013     object
# 2012     object
# 2011     object
# 2010     object
# 2009     object
# 2008     object
# dtype: object

# %% [markdown]
# Change Data Types

# %%
# Make Year columns int
df_incom['2022'] = df_incom['2022'].astype(str).astype(float)
df_incom['2021'] = df_incom['2021'].astype(str).astype(float)
df_incom['2020'] = df_incom['2020'].astype(str).astype(float)
df_incom['2019'] = df_incom['2019'].astype(str).astype(float)
df_incom['2018'] = df_incom['2018'].astype(str).astype(float)
df_incom['2017'] = df_incom['2017'].astype(str).astype(float)
df_incom['2016'] = df_incom['2016'].astype(str).astype(float)
df_incom['2015'] = df_incom['2015'].astype(str).astype(float)
df_incom['2014'] = df_incom['2014'].astype(str).astype(float)
df_incom['2013'] = df_incom['2013'].astype(str).astype(float)
df_incom['2012'] = df_incom['2012'].astype(str).astype(float)
df_incom['2011'] = df_incom['2011'].astype(str).astype(float)
df_incom['2010'] = df_incom['2010'].astype(str).astype(float)
df_incom['2009'] = df_incom['2009'].astype(str).astype(float)
df_incom['2008'] = df_incom['2008'].astype(str).astype(float)

# %%
# Check data types of df_incom
df_incom.dtypes
# Out:
# State     object
# 2022     float64
# 2021     float64
# 2020     float64
# 2019     float64
# 2018     float64
# 2017     float64
# 2016     float64
# 2015     float64
# 2014     float64
# 2013     float64
# 2012     float64
# 2011     float64
# 2010     float64
# 2009     float64
# 2008     float64
# dtype: object

# %% [markdown]
# Look for Missing Values

# %%
# List of missing values in df_incom
df_incom.isnull().sum()
# Out:
# State    0
# 2022     0
# 2021     0
# 2020     0
# 2019     0
# 2018     0
# 2017     0
# 2016     0
# 2015     0
# 2014     0
# 2013     0
# 2012     0
# 2011     0
# 2010     0
# 2009     0
# 2008     0
# dtype: int64

# %% [markdown]
# Overview of Data

# %%
df_incom.describe()
# Out:
#                 2022          2021          2020          2019          2018  \
# count      51.000000     51.000000     51.000000     51.000000     51.000000
# mean    75458.039216  71538.431373  68660.392157  69720.588235  64411.176471
# std     13087.457204  11825.417941  11823.964980  11714.799599  10364.177275
# min     48610.000000  46640.000000  45130.000000  44790.000000  42780.000000
# 25%     67350.000000  62790.000000  60360.000000  60880.000000  57560.000000
# 50%     73330.000000  71140.000000  67410.000000  70030.000000  62540.000000
# 75%     85235.000000  80700.000000  78200.000000  76260.000000  70320.000000
# max    108200.000000  97330.000000  94790.000000  95570.000000  86350.000000
#
#                2017          2016          2015          2014          2013  \
# count     51.000000     51.000000     51.000000     51.000000     51.000000
# mean   61518.039216  59179.607843  57012.352941  55224.117647  54316.078431
# ...

# %%
df_incom.shape
# Out:
# (51, 16)

# %%
# Change States to abbreviation to prepare for merge
df_incom['State'] = df_inc['State'].replace({'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 
                                          'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 
                                          'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 
                                          'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 
                                          'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 
                                          'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 
                                          'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 
                                           'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 
                                          'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Washington': 'WA', 'West Virginia': 'WV', 
                                          'Wisconsin': 'WI', 'Wyoming': 'WY', 'Virginia': 'VA'})

# %%
df_incom
# Out:
#                    State      2022     2021     2020     2019     2018  \
# 1                     AL   59910.0  56930.0  54690.0  56200.0  49940.0
# 2                     AK   89740.0  81130.0  74750.0  78390.0  68730.0
# 3                     AZ   73450.0  70820.0  67090.0  70670.0  62280.0
# 4                     AR   53980.0  50780.0  50780.0  54540.0  49780.0
# 5                     CA   85300.0  81580.0  77650.0  78110.0  70490.0
# 6                     CO   89930.0  84950.0  83780.0  72500.0  73030.0
# 7                     CT   90730.0  80960.0  79430.0  87290.0  72810.0
# 8                     DE   80750.0  68690.0  70020.0  74190.0  65010.0
# 9   District of Columbia  101700.0  90640.0  88220.0  93110.0  85750.0
# 10                    FL   65370.0  59730.0  57760.0  58370.0  54640.0
# 11                    GA   67730.0  61500.0  59270.0  56630.0  55820.0
# 12                    HI   91010.0  82200.0  80830.0  88010.0  80110.0
# ...

# %%
# Drop DC- Other data set does not contain this value
df_clean = df_incom[df_incom['State'] != 'District of Columbia']

# %%
# Drop VT- Other data set does not contain this value
df_clean_2 = df_clean[df_clean['State'] != 'VT']

# %%
# Drop VT- Other data set does not contain this value
df_clean_2 = df_clean_2[df_clean_2['State'] != 'AK']

# %%
df_clean_2
# Out:
#    State      2022     2021     2020     2019     2018     2017     2016  \
# 1     AL   59910.0  56930.0  54690.0  56200.0  49940.0  50870.0  47220.0
# 3     AZ   73450.0  70820.0  67090.0  70670.0  62280.0  59700.0  57100.0
# 4     AR   53980.0  50780.0  50780.0  54540.0  49780.0  49750.0  45910.0
# 5     CA   85300.0  81580.0  77650.0  78110.0  70490.0  70040.0  66640.0
# 6     CO   89930.0  84950.0  83780.0  72500.0  73030.0  74980.0  70570.0
# 7     CT   90730.0  80960.0  79430.0  87290.0  72810.0  74300.0  75920.0
# 8     DE   80750.0  68690.0  70020.0  74190.0  65010.0  64960.0  58050.0
# 10    FL   65370.0  59730.0  57760.0  58370.0  54640.0  53090.0  51180.0
# 11    GA   67730.0  61500.0  59270.0  56630.0  55820.0  57990.0  53530.0
# 12    HI   91010.0  82200.0  80830.0  88010.0  80110.0  73600.0  72130.0
# 13    ID   72580.0  76920.0  66730.0  65990.0  58730.0  59500.0  56560.0
# 14    IL   78020.0  79250.0  74330.0  74400.0  70150.0  65970.0  61390.0
# ...

# %%
df_clean_2.shape
# Out:
# (48, 16)

# %% [markdown]
# ## Transpose Data

# %%
# Transposed Data to have 3 columns: State, Year, Income
df_transposed =df_clean_2.melt(id_vars=['State'], var_name='Year', value_name='Income')

# %%
df_transposed
# Out:
#     State  Year   Income
# 0      AL  2022  59910.0
# 1      AZ  2022  73450.0
# 2      AR  2022  53980.0
# 3      CA  2022  85300.0
# 4      CO  2022  89930.0
# ..    ...   ...      ...
# 715    VA  2008  61990.0
# 716    WA  2008  56630.0
# 717    WV  2008  37990.0
# 718    WI  2008  51200.0
# 719    WY  2008  53340.0
#
# [720 rows x 3 columns]

# %%
# Make a new order for the COlumns
new_order = ['Year', 'State', 'Income']

# %%
# Reorder the columns
df_transposed = df_transposed[new_order]
df_transposed
# Out:
#      Year State   Income
# 0    2022    AL  59910.0
# 1    2022    AZ  73450.0
# 2    2022    AR  53980.0
# 3    2022    CA  85300.0
# 4    2022    CO  89930.0
# ..    ...   ...      ...
# 715  2008    VA  61990.0
# 716  2008    WA  56630.0
# 717  2008    WV  37990.0
# 718  2008    WI  51200.0
# 719  2008    WY  53340.0
#
# [720 rows x 3 columns]

# %%
df_transposed = df_transposed.sort_values(by=['Year', 'State'])
df_transposed
# Out:
#      Year State   Income
# 672  2008    AL  44480.0
# 674  2008    AR  39590.0
# 673  2008    AZ  46910.0
# 675  2008    CA  57010.0
# 676  2008    CO  60940.0
# ..    ...   ...      ...
# 43   2022    VA  85170.0
# 44   2022    WA  89430.0
# 46   2022    WI  73330.0
# 45   2022    WV  52460.0
# 47   2022    WY  73090.0
#
# [720 rows x 3 columns]

# %%
df_transposed = df_transposed.reset_index(drop=True)
df_transposed
# Out:
#      Year State   Income
# 0    2008    AL  44480.0
# 1    2008    AR  39590.0
# 2    2008    AZ  46910.0
# 3    2008    CA  57010.0
# 4    2008    CO  60940.0
# ..    ...   ...      ...
# 715  2022    VA  85170.0
# 716  2022    WA  89430.0
# 717  2022    WI  73330.0
# 718  2022    WV  52460.0
# 719  2022    WY  73090.0
#
# [720 rows x 3 columns]

# %% [markdown]
# ## Export Data

# %%
# Rename and Export df_incom
df_transposed.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Income_Cleaned.csv'))
